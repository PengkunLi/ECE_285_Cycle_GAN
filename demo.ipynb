# %%
from TrainCycleGan import *
# Out:
# cuda
# /datasets/home/home-02/58/258/jil046/ECE 285/Cycle-GAN
# 3781
# 4176
# torch.Size([3, 190, 190])

# %%
exp_demo = train_module(netG_A2B, netG_B2A, netD_A, netD_B, opt, train_loader,                  
                    val_loader, test_loader, criterion_identity,      
                    criterion_GAN, criterion_cycle , optimizer_G, 
                    optimizer_D, output_dir = 'check0')
# Out:
# check0/checkpoint.pth.tar

# %%
exp_demo.demo()

# %%
exp_demo.plot_loss()
